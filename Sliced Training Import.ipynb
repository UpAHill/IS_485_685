# %% [markdown]
# # Sliced Training Import

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/adriennehill/Desktop/Notebooks/demo/IS_485_685/sliced_training.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Index  Account Balance  Duration of Credit (month)  \
# 0           0    845                1                          18
# 1           1    659                1                           9
# 2           3    194                1                          12
# 3           4    213                1                          12
# 4           5    625                1                          10
#
#    Payment Status of Previous Credit  Purpose   Amount  Value Savings/Stocks  \
# 0                                  4        2     1049                     1
# 1                                  4        0     2799                     1
# 2                                  4        0     2122                     1
# 3                                  4        0     2171                     1
# 4                                  4        0     2241                     1
#
#    Length of current employment  Instalment per cent       ...        \
# ...

# %%
plt.hist(df['Length of current employment'])
plt.show()

# %%
plt.hist(df['Length of current employment'],4)
plt.show()

# %%
df.iloc[:,-3]
# Out:
# 0      1
# 1      2
# 2      2
# 3      1
# 4      2
# 5      1
# 6      2
# 7      1
# 8      1
# 9      2
# 10     1
# 11     1
# 12     1
# 13     1
# 14     2
# 15     2
# 16     1
# 17     1
# 18     1
# 19     2
# 20     2
# 21     1
# 22     1
# 23     2
# 24     1
# 25     1
# 26     1
# 27     1
# 28     1
# 29     1
#       ..
# 583    1
# 584    2
# 585    1
# 586    1
# 587    1
# 588    1
# 589    1
# 590    2
# 591    2
# 592    1
# 593    1
# 594    1
# 595    1
# 596    1
# 597    2
# 598    1
# 599    1
# 600    1
# 601    1
# 602    1
# 603    1
# 604    1
# 605    1
# 606    1
# 607    1
# 608    1
# 609    1
# 610    1
# 611    1
# 612    1
# Name: No of dependents, Length: 613, dtype: int64

# %%
plt.title('Distribution of Length of Current Employment')
plt.hist(df['Length of current employment'])
plt.show()

# %%
df.dtypes
# Out:
# Unnamed: 0                           int64
# Index                                int64
# Account Balance                      int64
# Duration of Credit (month)           int64
# Payment Status of Previous Credit    int64
# Purpose                              int64
#  Amount                              int64
# Value Savings/Stocks                 int64
# Length of current employment         int64
# Instalment per cent                  int64
# Sex & Marital Status                 int64
# Guarantors                           int64
# Duration in Current address          int64
# Most valuable available asset        int64
# Age (years)                          int64
# Concurrent Credits                   int64
# Type of apartment                    int64
# No of Credits at this Bank           int64
# Occupation                           int64
# No of dependents                     int64
# Telephone                            int64
# Foreign Worker                       int64
# ...

# %%
pd.DataFrame.from_dict[df]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-ef34c01440a9> in <module>()
# ----> 1 pd.DataFrame.from_dict[df]
#
# TypeError: 'method' object is not subscriptable

# %%
df
# Out:
#      Unnamed: 0  Index  Account Balance  Duration of Credit (month)  \
# 0             0    845                1                          18
# 1             1    659                1                           9
# 2             3    194                1                          12
# 3             4    213                1                          12
# 4             5    625                1                          10
# 5             6    925                1                           8
# 6             7    378                1                           6
# 7             8    906                4                          18
# 8             9    950                2                          24
# 9            10    456                1                          11
# 10           11    755                1                          30
# 11           12    874                1                           6
# 12           13    686                2                          48
# ...

# %%
df.T
# Out:
#                                     0     1     2     3     4     5     6    \
# Unnamed: 0                            0     1     3     4     5     6     7
# Index                               845   659   194   213   625   925   378
# Account Balance                       1     1     1     1     1     1     1
# Duration of Credit (month)           18     9    12    12    10     8     6
# Payment Status of Previous Credit     4     4     4     4     4     4     4
# Purpose                               2     0     0     0     0     0     0
#  Amount                            1049  2799  2122  2171  2241  3398  1361
# Value Savings/Stocks                  1     1     1     1     1     1     1
# Length of current employment          2     3     3     3     2     4     2
# Instalment per cent                   4     2     3     4     1     1     2
# Sex & Marital Status                  2     3     3     3     3     3     3
# ...

# %%
df.T
df
# Out:
#      Unnamed: 0  Index  Account Balance  Duration of Credit (month)  \
# 0             0    845                1                          18
# 1             1    659                1                           9
# 2             3    194                1                          12
# 3             4    213                1                          12
# 4             5    625                1                          10
# 5             6    925                1                           8
# 6             7    378                1                           6
# 7             8    906                4                          18
# 8             9    950                2                          24
# 9            10    456                1                          11
# 10           11    755                1                          30
# 11           12    874                1                           6
# 12           13    686                2                          48
# ...

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=613, step=1),
#  Index(['Unnamed: 0', 'Index', 'Account Balance', 'Duration of Credit (month)',
#         'Payment Status of Previous Credit', 'Purpose', ' Amount',
#         'Value Savings/Stocks', 'Length of current employment',
#         'Instalment per cent', 'Sex & Marital Status', 'Guarantors',
#         'Duration in Current address', 'Most valuable available asset',
#         'Age (years)', 'Concurrent Credits', 'Type of apartment',
#         'No of Credits at this Bank', 'Occupation', 'No of dependents',
#         'Telephone', 'Foreign Worker'],
#        dtype='object')]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Index', 'Account Balance', 'Duration of Credit (month)',
#        'Payment Status of Previous Credit', 'Purpose', ' Amount',
#        'Value Savings/Stocks', 'Length of current employment',
#        'Instalment per cent', 'Sex & Marital Status', 'Guarantors',
#        'Duration in Current address', 'Most valuable available asset',
#        'Age (years)', 'Concurrent Credits', 'Type of apartment',
#        'No of Credits at this Bank', 'Occupation', 'No of dependents',
#        'Telephone', 'Foreign Worker'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=613, step=1)

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (613, 22)

# %%
df.size
# Out:
# 13486

# %%
df.style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_df0d79b4_b653_11e8_884e_34363b7ef4cc" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Unnamed: 0</th>
#         <th class="col_heading level0 col1" >Index</th>
#         <th class="col_heading level0 col2" >Account Balance</th>
#         <th class="col_heading level0 col3" >Duration of Credit (month)</th>
#         <th class="col_heading level0 col4" >Payment Status of Previous Credit</th>
#         <th class="col_heading level0 col5" >Purpose</th>
#         <th class="col_heading level0 col6" > Amount</th>
#         <th class="col_heading level0 col7" >Value Savings/Stocks</th>
#         <th class="col_heading level0 col8" >Length of current employment</th>
#         <th class="col_heading level0 col9" >Instalment per cent</th>
#         <th class="col_heading level0 col10" >Sex & Marital Status</th>
#         <th class="col_heading level0 col11" >Guarantors</th>
# ...

# %%
df.values
# Out:
# array([[  0, 845,   1, ...,   1,   1,   1],
#        [  1, 659,   1, ...,   2,   1,   1],
#        [  3, 194,   1, ...,   2,   1,   2],
#        ...,
#        [696, 535,   3, ...,   1,   2,   1],
#        [697, 229,   4, ...,   1,   1,   1],
#        [698, 601,   2, ...,   1,   1,   1]])

# %%
df.empty
# Out:
# False

# %%
df.ftypes
# Out:
# Unnamed: 0                           int64:dense
# Index                                int64:dense
# Account Balance                      int64:dense
# Duration of Credit (month)           int64:dense
# Payment Status of Previous Credit    int64:dense
# Purpose                              int64:dense
#  Amount                              int64:dense
# Value Savings/Stocks                 int64:dense
# Length of current employment         int64:dense
# Instalment per cent                  int64:dense
# Sex & Marital Status                 int64:dense
# Guarantors                           int64:dense
# Duration in Current address          int64:dense
# Most valuable available asset        int64:dense
# Age (years)                          int64:dense
# Concurrent Credits                   int64:dense
# Type of apartment                    int64:dense
# No of Credits at this Bank           int64:dense
# Occupation                           int64:dense
# ...

# %%
df.ix
# Out:
# /Users/adriennehill/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
